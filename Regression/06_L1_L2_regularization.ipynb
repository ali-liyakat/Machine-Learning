# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("dataset.csv")
df.head()
# Out:
#          f1        f2        f3  ...      f149      f150      target
# 0 -0.924357 -0.326536 -1.875007  ...  0.005113 -0.234587   10.681366
# 1  0.001795 -1.285599 -0.726774  ...  0.058209 -1.142970  -60.163343
# 2  0.956702  2.319330 -0.705012  ...  0.812862  0.629629  131.226545
# 3 -0.982294  0.190424  1.082691  ... -0.114540  1.237816 -131.889020
# 4 -0.057061 -0.592465 -2.850030  ... -0.875618 -1.382800 -138.566956
#
# [5 rows x 151 columns]

# %%
X = df.drop(['target'], axis=1)
y = df.target
X.head()
# Out:
#          f1        f2        f3  ...      f148      f149      f150
# 0 -0.924357 -0.326536 -1.875007  ...  0.261055  0.005113 -0.234587
# 1  0.001795 -1.285599 -0.726774  ...  0.153725  0.058209 -1.142970
# 2  0.956702  2.319330 -0.705012  ...  0.307300  0.812862  0.629629
# 3 -0.982294  0.190424  1.082691  ...  1.353872 -0.114540  1.237816
# 4 -0.057061 -0.592465 -2.850030  ... -0.190339 -0.875618 -1.382800
#
# [5 rows x 150 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# # Linear Regression

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
lm.score(X_test, y_test)
# Out:
# 0.7410183335246836

# %%
lm

# %% [markdown]
# # Lasso Regression L1

# %%
lasso = Lasso(alpha=1.0)
lasso.fit(X_train, y_train)
lasso.score(X_test, y_test)
# Out:
# 0.9901476660336155

# %% [markdown]
# # Ridge Regression L2

# %%
ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train)
ridge.score(X_test, y_test)
# Out:
# 0.9462671341742038
